# %%
import seaborn as sns

# %%
df=sns.load_dataset('titanic')

# %%
df.shape
# Out:
# (891, 15)

# %%
df.head(4)
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
#
#    adult_male deck  embark_town
# 0        True    C  Southampton
# 1       False    C    Cherbourg
# 2       False    C  Southampton
# 3       False    C  Southampton

# %%
df.count()
# Out:
# survived       891
# pclass         891
# sex            891
# age            714
# sibsp          891
# parch          891
# fare           891
# embarked       889
# class          891
# who            891
# adult_male     891
# deck           203
# embark_town    889
# alive          891
# alone          891
# dtype: int64

# %%
df.sample(4)
# Out:
#      survived  pclass   sex   age  sibsp  parch     fare embarked   class  \
# 174         0       1  male  56.0      0      0  30.6958        C   First
# 277         0       2  male   NaN      0      0   0.0000        S  Second
# 221         0       2  male  27.0      0      0  13.0000        S  Second
# 59          0       3  male  11.0      5      2  46.9000        S   Third
#
#        who  adult_male deck  embark_town alive  alone
# 174    man        True    A    Cherbourg    no   True
# 277    man        True  NaN  Southampton    no   True
# 221    man        True  NaN  Southampton    no   True
# 59   child       False  NaN  Southampton    no  False

# %%
df.tail(4)
# Out:
#      survived  pclass     sex   age  sibsp  parch   fare embarked  class  \
# 887         1       1  female  19.0      0      0  30.00        S  First
# 888         0       3  female   NaN      1      2  23.45        S  Third
# 889         1       1    male  26.0      0      0  30.00        C  First
# 890         0       3    male  32.0      0      0   7.75        Q  Third
#
#        who  adult_male deck  embark_town alive  alone
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True

# %%
df['fare'].min()
# Out:
# np.float64(0.0)

# %%
df['fare'].max()
# Out:
# np.float64(512.3292)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.duplicated().sum()
# Out:
# np.int64(107)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True,inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            106
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['age'].fillna(df['age'].median(),inplace=True)
# Out:
# /tmp/ipykernel_10693/2790788646.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['age'].fillna(df['age'].median(),inplace=True)

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           582
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_10693/1024298632.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embarked'].fillna(df['embarked'].mode()[0],inplace=True)

# %%
df['deck'].fillna(df['deck'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_10693/3365195351.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['deck'].fillna(df['deck'].mode()[0],inplace=True)

# %%
df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)
# Out:
# /tmp/ipykernel_10693/751922478.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['embark_town'].fillna(df['embark_town'].mode()[0],inplace=True)

# %%
df.drop(columns=['who','alive'],inplace=True)

# %%
df.drop(columns='alone',inplace=True)

# %%
# count plot
# box plot
# scatter plot
# scatter (
#     any 2 numerical
#     1 categorical
#     2 categorical
# )
# same for regression plot
# heatmap

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[79], line 2
#       1 for i in df.columns:
# ----> 2     sns.scatterplot(i,data=df)
#
# TypeError: scatterplot() got multiple values for argument 'data'

# %%
df.count()
# Out:
# survived       784
# pclass         784
# sex            784
# age            784
# sibsp          784
# parch          784
# fare           784
# embarked       784
# class          784
# adult_male     784
# deck           784
# embark_town    784
# dtype: int64

# %%
sns.countplot(x='survived',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.boxplot(y='survived',data=df)
# Out:
# <Axes: ylabel='survived'>

# %%
sns.scatterplot(x='survived',y='sex',data=df)
# Out:
# <Axes: xlabel='survived', ylabel='sex'>

# %%
sns.countplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='sex',data=df)
# Out:
# <Axes: xlabel='sex'>

# %%
sns.countplot(x='sibsp',data=df)
# Out:
# <Axes: xlabel='sibsp', ylabel='count'>

# %%
sns.boxplot(x='sibsp',data=df)
# Out:
# <Axes: xlabel='sibsp'>

# %%
sns.countplot(x='parch',data=df)
# Out:
# <Axes: xlabel='parch', ylabel='count'>

# %%
sns.boxplot(x='parch',data=df)
# Out:
# <Axes: xlabel='parch'>

# %%
sns.boxplot(x='fare',data=df)
# Out:
# <Axes: xlabel='fare'>

# %%
sns.countplot(x='fare',data=df)
# Out:
# <Axes: xlabel='fare', ylabel='count'>

# %%
sns.countplot(x='embarked',data=df)
# Out:
# <Axes: xlabel='embarked', ylabel='count'>

# %%
sns.boxplot(x='embarked',data=df)
# Out:
# <Axes: xlabel='embarked'>

# %%
sns.countplot(x='class',data=df)
# Out:
# <Axes: xlabel='class', ylabel='count'>

# %%
sns.boxplot(x='class',data=df)
# Out:
# <Axes: xlabel='class'>

# %%
sns.countplot(x='adult_male',data=df)
# Out:
# <Axes: xlabel='adult_male', ylabel='count'>

# %%
sns.boxplot(x='adult_male',data=df)
# Out:
# <Axes: xlabel='adult_male'>

# %%
sns.countplot(x='deck',data=df)
# Out:
# <Axes: xlabel='deck', ylabel='count'>

# %%
sns.boxplot(x='deck',data=df)
# Out:
# <Axes: xlabel='deck'>

# %%
sns.countplot(x='embark_town',data=df)
# Out:
# <Axes: xlabel='embark_town', ylabel='count'>

# %%
sns.boxplot(x='embark_town',data=df)
# Out:
# <Axes: xlabel='embark_town'>

# %%
import matplotlib.pyplot as plt
df.info()
# for i in range(len(df.columns)-1):
#     sns.scatterplot(data=df, x=df[i], y=df[i+1])
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 784 entries, 0 to 783
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     784 non-null    int64
#  1   pclass       784 non-null    int64
#  2   sex          784 non-null    object
#  3   age          784 non-null    float64
#  4   sibsp        784 non-null    int64
#  5   parch        784 non-null    int64
#  6   fare         784 non-null    float64
#  7   embarked     784 non-null    object
#  8   class        784 non-null    category
#  9   adult_male   784 non-null    bool
#  10  deck         784 non-null    category
#  11  embark_town  784 non-null    object
# dtypes: bool(1), category(2), float64(2), int64(4), object(3)
# memory usage: 58.0+ KB

# %%
col = ['age', 'fare', 'sibsp', 'parch', 'pclass', 'survived','sex','embarked','class','adult_male','deck','embark_town']

plt.figure(figsize=(15,10))
for i in range(len(col)-1):
    plt.subplot(4, 3, i+1)
    sns.scatterplot(data=df, x=col[i], y=col[i+1])

# %%
col = ['age', 'fare', 'sibsp', 'parch', 'pclass', 'survived','sex','embarked','class','adult_male','deck','embark_town']

plt.figure(figsize=(15,10))
for i in range(len(col)-1):
    plt.subplot(4, 3, i+1)
    sns.countplot(data=df, x=col[i])
