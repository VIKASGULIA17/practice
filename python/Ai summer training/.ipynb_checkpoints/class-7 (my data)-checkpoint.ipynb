# %%
import pandas as pd

# %% [markdown]
# # Data loading

# %%
df=pd.read_csv('/home/shino/Documents/Datasets/realistic_linear_dataset.csv')

# %%
df
# Out:
#        Feature1   Feature2    Feature3      Target
# 0     54.967142  44.426389  126.709483   58.158206
# 1     48.617357        NaN  115.103022   18.579202
# 2     56.476885  40.929232  157.590969    7.364046
# 3     65.230299  26.659886   63.013894  158.316361
# 4     47.658466  68.494113  131.480831   93.991703
# ...         ...        ...         ...         ...
# 1995  60.701502  36.997064   81.900882  125.018754
# 1996  49.734787  44.018770   83.891493  101.012461
# 1997  41.181253  68.711967   31.521495  221.865269
# 1998  48.369330  20.831728  129.653637   -3.745338
# 1999        NaN  58.962729  138.508099   39.513708
#
# [2000 rows x 4 columns]

# %% [markdown]
# # information gathering

# %%
# checking dimensions 
df.shape
# Out:
# (2000, 4)

# %%
df.count()
# Out:
# Feature1    1900
# Feature2    1900
# Feature3    1900
# Target      1900
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Feature1  1900 non-null   float64
#  1   Feature2  1900 non-null   float64
#  2   Feature3  1900 non-null   float64
#  3   Target    1900 non-null   float64
# dtypes: float64(4)
# memory usage: 62.6 KB

# %%
df.describe()
# Out:
#           Feature1     Feature2     Feature3       Target
# count  1900.000000  1900.000000  1900.000000  1900.000000
# mean     50.497866    49.614128    98.905012   101.189351
# std       9.870636    17.230923    24.556084    59.861173
# min      17.587327    20.000698    20.739357   -84.501965
# 25%      43.880638    34.810924    82.840295    61.129043
# 50%      50.486908    49.910768    99.446077   101.033355
# 75%      56.908844    64.081261   115.663930   142.873464
# max      88.527315    79.973462   178.801418   298.968346

# %%
df.head(3)
# Out:
#     Feature1   Feature2    Feature3     Target
# 0  54.967142  44.426389  126.709483  58.158206
# 1  48.617357        NaN  115.103022  18.579202
# 2  56.476885  40.929232  157.590969   7.364046

# %%
df.sample(4)
# Out:
#        Feature1   Feature2    Feature3      Target
# 199   38.570297  28.817763  132.581951  -24.580300
# 1264  51.693608  33.591298         NaN   28.178023
# 866   52.858654  67.024295   71.072085  174.196605
# 321   55.951570  41.183023  105.463351   91.158720

# %%
df.tail(3)
# Out:
#        Feature1   Feature2    Feature3      Target
# 1997  41.181253  68.711967   31.521495  221.865269
# 1998  48.369330  20.831728  129.653637   -3.745338
# 1999        NaN  58.962729  138.508099   39.513708

# %% [markdown]
# # Data cleaning

# %%
# checking duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#        Feature1   Feature2    Feature3      Target
# 0     54.967142  44.426389  126.709483   58.158206
# 1     48.617357        NaN  115.103022   18.579202
# 2     56.476885  40.929232  157.590969    7.364046
# 3     65.230299  26.659886   63.013894  158.316361
# 4     47.658466  68.494113  131.480831   93.991703
# ...         ...        ...         ...         ...
# 1995  60.701502  36.997064   81.900882  125.018754
# 1996  49.734787  44.018770   83.891493  101.012461
# 1997  41.181253  68.711967   31.521495  221.865269
# 1998  48.369330  20.831728  129.653637   -3.745338
# 1999        NaN  58.962729  138.508099   39.513708
#
# [2000 rows x 4 columns]

# %%
df.isnull().sum()
# Out:
# Feature1    100
# Feature2    100
# Feature3    100
# Target      100
# dtype: int64

# %%
df['Feature1'].fillna(df['Feature1'].mean(),inplace=True)
df['Feature2'].fillna(df['Feature2'].mean(),inplace=True)
df['Feature3'].fillna(df['Feature3'].mean(),inplace=True)
df['Target'].fillna(df['Target'].mean(),inplace=True)
# Out:
# /tmp/ipykernel_47228/3264202697.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Feature1'].fillna(df['Feature1'].mean(),inplace=True)
# /tmp/ipykernel_47228/3264202697.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=df.iloc[:,:3]

# %%
y=df['Target']
x,y
# Out:
# (       Feature1   Feature2    Feature3
#  0     54.967142  44.426389  126.709483
#  1     48.617357  49.614128  115.103022
#  2     56.476885  40.929232  157.590969
#  3     65.230299  26.659886   63.013894
#  4     47.658466  68.494113  131.480831
#  ...         ...        ...         ...
#  1995  60.701502  36.997064   81.900882
#  1996  49.734787  44.018770   83.891493
#  1997  41.181253  68.711967   31.521495
#  1998  48.369330  20.831728  129.653637
#  1999  50.497866  58.962729  138.508099
#
#  [2000 rows x 3 columns],
#  0        58.158206
#  1        18.579202
#  2         7.364046
#  3       158.316361
#  4        93.991703
#             ...
#  1995    125.018754
#  1996    101.012461
#  1997    221.865269
#  1998     -3.745338
#  1999     39.513708
#  Name: Target, Length: 2000, dtype: float64)

# %%
# creating scatter plot

sns.scatterplot(df)
# Out:
# <Axes: >

# %%
# creating boxplot

sns.boxplot(x)
# Out:
# <Axes: >

# %%
sns.boxplot(y)
# Out:
# <Axes: ylabel='Target'>

# %%
# creating heatmap
sns.heatmap(df)
# Out:
# <Axes: >

# %%
sns.regplot(x='Feature1',y='Feature2',data=df)
# Out:
# <Axes: xlabel='Feature1', ylabel='Feature2'>

# %%
import numpy as np

# %% [markdown]
# # checking for outlier

# %%
# function to check for outliers
def handle_outlier(column):
    q1=df[column].quantile(.25)
    q3=df[column].quantile(.75)
    iqr=q3-q1

    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)

    return  df[(df[column]<lower_range) | (df[column]>upper_range)]

# %%
handle_outlier('Feature1')
# Out:
#        Feature1   Feature2    Feature3      Target
# 74    23.802549  46.029045  129.818379  -36.138166
# 179   77.201692  33.694122   86.176979  153.494025
# 209   88.527315  73.408468   74.603029  294.000689
# 262   17.587327  34.840419  132.401577  -70.036225
# 478   80.788808  76.666915   70.269188  298.968346
# 544   25.283555  49.614128   97.229686    9.868380
# 646   23.031134  41.265497  135.877185  -58.505408
# 654   75.733598  31.631784  100.630272  133.469887
# 668   23.490302  29.917069   97.707349  -26.290369
# 755   76.323821  39.269729  100.682834  157.243404
# 762   75.600845  63.364265   93.773204  199.333714
# 880   75.269324  71.865995   98.905012  207.796255
# 977   25.761207  28.836534   69.270410   29.116796
# 1061  21.514574  78.195592  115.665341   43.992121
# 1160  25.005943  36.896963  127.598339  -33.643427
# 1233  75.797093  39.607682   99.647526  162.706732
# 1291  74.929995  61.031987  134.347860  144.889437
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Feature1  2000 non-null   float64
#  1   Feature2  2000 non-null   float64
#  2   Feature3  2000 non-null   float64
#  3   Target    2000 non-null   float64
# dtypes: float64(4)
# memory usage: 62.6 KB

# %% [markdown]
# # Train test split

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=35,test_size=.1)

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import StandardScaler

for i in range(50):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.1)


# scaling values

    ss=StandardScaler()
    x_train=ss.fit_transform(x_train)
    x_test=ss.transform(x_test)



# training model

    lr=LinearRegression()
    lr.fit(x_train,y_train)


    y_pred=lr.predict(x_test)
    score=r2_score(y_test,y_pred)
    
    print(f"score at random state {i} is {score*100}")
# Out:
# score at random state 0 is 86.50110167702715
# score at random state 1 is 84.33103966663576
# score at random state 2 is 87.32816153897295
# score at random state 3 is 87.34475901445201
# score at random state 4 is 80.36022752398846
# score at random state 5 is 90.07052622979963
# score at random state 6 is 86.49236673436958
# score at random state 7 is 89.99816065176093
# score at random state 8 is 86.23225516922423
# score at random state 9 is 88.46222067502048
# score at random state 10 is 82.84309648264248
# score at random state 11 is 84.05376532471239
# score at random state 12 is 89.84140942022366
# score at random state 13 is 88.47166028726757
# score at random state 14 is 90.15906141047738
# score at random state 15 is 85.57213100953993
# score at random state 16 is 86.83544599096118
# score at random state 17 is 86.85527549769513
# score at random state 18 is 86.89169953266845
# score at random state 19 is 87.30267638417854
# score at random state 20 is 78.33941333620609
# ...

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaling values

ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %% [markdown]
# # making model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# training model

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9124412917870747

# %%
# 9085792494774949 - when test size is .2 
# 9086544902864333 - when test size is .3
# 0.8487119973053087 -when test size is .35

# %%
df.sample(3)
# Out:
#        Feature1   Feature2   Feature3      Target
# 573   47.808995  34.853586  54.091005  116.672466
# 1548  57.660803  20.820945  82.691231   85.307512
# 579   61.437540  24.868951  82.200669  115.133646
