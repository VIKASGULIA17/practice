# %%
from PIL import Image
import matplotlib.pyplot as plt
import numpy as np

# %%
img=Image.open('mat-chu-dien-nam.webp')
arr=np.array(img)
arr[185:270,280:430,2]=0
arr[220:450,250:430,2]=0
arr[185:270,430:560,0]=0
arr[220:450,430:570,0]=0

arr[450:560,250:430,1]=0
arr[560:600,265:430,1]=0
arr[600:610,275:430,1]=0
arr[610:620,285:430,1]=0
arr[620:660,295:430,1]=0

arr[450:560,430:570,2]=0
arr[480:605,430:540,2]=0
arr[480:660,430:520,2]=0

plt.imshow(arr)

# %%
import pandas as pd

# %%
pd.DataFrame({
    'C.name':['Amazon','Google','Netflix','Apple'],
    'Location':['Delhi',"Mumbai","Up","Kolkata"],
    'Emp.Count':[500,345,643,876],
    'Ranking':[1,2,3,4]
})
# Out:
#     C.name Location  Emp.Count  Ranking
# 0   Amazon    Delhi        500        1
# 1   Google   Mumbai        345        2
# 2  Netflix       Up        643        3
# 3    Apple  Kolkata        876        4

# %%
pd.DataFrame(
   [
    ['Duke', 'V4', 180000, 'Mumbai', 'India'],
    ['pulsor', 'BS6', 210000, 'Delhi', 'India'],
    ['zxnr', 'ABS', 190000, 'Bangalore', 'India'],
    ['cbr', 'MotoGP', 160000, 'Chennai', 'India'],
    ['jixxar', 'Dual ABS', 170000, 'Pune', 'India'],
    ['s100rr', 'Race Tuned', 240000, 'Hyderabad', 'India'],
    ['m1000rr', 'Retro', 200000, 'Kolkata', 'India'],
    ['duke390', 'Street', 130000, 'Ahmedabad', 'India'],
    ['gt350', 'Sport', 290000, 'Chandigarh', 'India'],
    ['honda', 'Naked', 800000, 'Jaipur', 'India']
],
    index=[210,211,212,213,214,215,216,217,218,219],
    columns=['Name', 'model', 'price', 'location', 'country']

)
# Out:
#         Name       model   price    location country
# 210     Duke          V4  180000      Mumbai   India
# 211   pulsor         BS6  210000       Delhi   India
# 212     zxnr         ABS  190000   Bangalore   India
# 213      cbr      MotoGP  160000     Chennai   India
# 214   jixxar    Dual ABS  170000        Pune   India
# 215   s100rr  Race Tuned  240000   Hyderabad   India
# 216  m1000rr       Retro  200000     Kolkata   India
# 217  duke390      Street  130000   Ahmedabad   India
# 218    gt350       Sport  290000  Chandigarh   India
# 219    honda       Naked  800000      Jaipur   India

# %%
df=pd.read_csv('movie_genre_classification_final.csv')
df
# Out:
#                  Title  Year    Director  Duration  Rating   Votes  \
# 0      Winds of Fate 4  1980      R. Lee       167     4.1  182425
# 1         Firestorm 11  2014     S. Chen       166     4.1  449351
# 2        Silent Echo 2  2016     A. Khan       170     4.1  363328
# 3        City Lights 4  1982    L. Zhang       170     9.9   62371
# 4       Broken Truth 1  1990    L. Zhang        91     5.3    4600
# ...                ...   ...         ...       ...     ...     ...
# 49995    Ocean Call 20  2013  T. Johnson       149     6.8  340904
# 49996    Ocean Call 13  2001    M. Brown       166     7.6  214228
# 49997  Last Mission 15  2017    J. Smith       158     9.2  251931
# 49998     Firestorm 11  1992    J. Smith       166     7.2  487956
# 49999   Silent Echo 12  2009    P. Adams       117     4.3  392762
#
#                                              Description  Language  \
# 0       A touching love story with heartwarming moments.   Spanish
# ...

# %%
df1=pd.Series(['mango','apple','banana','cucumber','grapes'],
         index=[200,300,244,324,234])
df1
# Out:
# 200       mango
# 300       apple
# 244      banana
# 324    cucumber
# 234      grapes
# dtype: object

# %%
df1=pd.Series([99,98,79,89,93],
         index=['Vikas','Tanish','Rohan','Tushar','Aaksh'])
df1
# Out:
# Vikas     99
# Tanish    98
# Rohan     79
# Tushar    89
# Aaksh     93
# dtype: int64

# %%
df=pd.read_csv('mtcars2.csv')

# %%
df.shape

df.info()

df.head()

df.tail()

df.sample()

df.describe().T

df.count()

df.duplicated().sum()

# %%
df.isnull().sum()
# Out:
# S.No          0
# Unnamed: 1    0
# mpg           0
# cyl           0
# disp          0
# hp            0
# drat          0
# wt            0
# qsec          3
# vs            0
# am            0
# gear          0
# carb          0
# dtype: int64

# %%
df['qsec'].fillna(df['qsec'].median(),inplace=True)
# Out:
# C:\Users\osame\AppData\Local\Temp\ipykernel_8988\144144815.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['qsec'].fillna(df['qsec'].median(),inplace=True)

# %%
df
# Out:
#     S.No           Unnamed: 1   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df.rename(columns={'Unnamed: 1':'Name'},inplace=True)

# %%
df
# Out:
#     S.No                 Name   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 0      1            Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0
# 1      2        Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0
# 2      3           Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1
# 3      4       Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1
# 4      5    Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0
# 5      6              Valiant  18.1    6  225.0  105  2.76  3.460  17.42   1
# 6      7           Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0
# 7      8            Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1
# 8      9             Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1
# 9     10             Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1
# 10    11            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1
# ...

# %%
df=pd.read_csv('IMBD.csv')

# %%
df
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (9957, 9)

# %%
(df.isnull().sum()/df.shape[0] )*100
# Out:
# title        0.000000
# year         5.292759
# duration    20.447926
# genre        0.733153
# rating      11.780657
# stars        0.000000
# votes       11.780657
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9957 non-null   object
#  1   year      9957 non-null   object
#  2   duration  9957 non-null   object
#  3   genre     9957 non-null   object
#  4   rating    9957 non-null   float64
#  5   stars     9957 non-null   object
#  6   votes     9957 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 544.7+ KB

# %%
df.drop(columns=['description','certificate'],inplace=True)

df['duration'].fillna(df['duration'].mode()[0],inplace=True)

df['rating'].fillna(df['rating'].median(),inplace=True)

df['votes']=df['votes'].astype(int)

type(df['votes'][0])

df['year'].fillna(df['year'].mode()[0],inplace=True)

(df.isnull().sum()/df.shape[0])*100

df['genre'].fillna(df['genre'].mode()[0],inplace=True)

# %%
df
# Out:
#                        title         year duration  \
# 0                  Cobra Kai     (2018– )   30 min
# 1                  The Crown     (2016– )   58 min
# 2           Better Call Saul  (2015–2022)   46 min
# 3              Devil in Ohio       (2022)  356 min
# 4     Cyberpunk: Edgerunners     (2022– )   24 min
# ...                      ...          ...      ...
# 9952          The Imperfects     (2022– )   45 min
# 9953        The Walking Dead  (2010–2022)   44 min
# 9954               The Crown     (2016– )   58 min
# 9955            Supernatural  (2005–2020)   44 min
# 9956           Devil in Ohio       (2022)  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...                            ...     ...
# ...
