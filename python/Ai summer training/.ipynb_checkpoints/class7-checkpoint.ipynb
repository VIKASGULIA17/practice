# %%
import pandas as pd

# %%
# df=pd.read_csv('/home/shino/Documents/Datasets/synthetic_vehicle_telemetry_dataset.csv')

# %% [markdown]
# # Data loading

# %%
df=pd.read_csv('/home/shino/Documents/Datasets/height-weight.csv')

# %%
df
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11      95     182
# 12     105     175
# 13     100     183
# 14      85     170
# 15      78     177
# 16      50     140
# 17      65     159
# 18      76     150
# 19      87     167
# 20      45     129
# 21      56     140
# 22      72     160

# %% [markdown]
# # information gathering

# %%
# checking dimensions 
df.shape
# Out:
# (23, 2)

# %%
df.count()
# Out:
# Weight    23
# Height    23
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Weight  23 non-null     int64
#  1   Height  23 non-null     int64
# dtypes: int64(2)
# memory usage: 500.0 bytes

# %%
df.describe()
# Out:
#            Weight      Height
# count   23.000000   23.000000
# mean    73.826087  158.391304
# std     17.872407   19.511626
# min     45.000000  120.000000
# 25%     59.000000  142.500000
# 50%     78.000000  162.000000
# 75%     86.000000  175.000000
# max    105.000000  183.000000

# %%
df.head(3)
# Out:
#    Weight  Height
# 0      45     120
# 1      58     135
# 2      48     123

# %%
df.sample(4)
# Out:
#     Weight  Height
# 2       48     123
# 1       58     135
# 9       78     170
# 20      45     129

# %%
df.tail(3)
# Out:
#     Weight  Height
# 20      45     129
# 21      56     140
# 22      72     160

# %% [markdown]
# # Data cleaning

# %%
# checking duplicates

df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#     Weight  Height
# 0       45     120
# 1       58     135
# 2       48     123
# 3       60     145
# 4       70     160
# 5       78     162
# 6       80     163
# 7       90     175
# 8       95     182
# 9       78     170
# 10      82     176
# 11     105     175
# 12     100     183
# 13      85     170
# 14      78     177
# 15      50     140
# 16      65     159
# 17      76     150
# 18      87     167
# 19      45     129
# 20      56     140
# 21      72     160

# %%
df.isnull().sum()
# Out:
# Weight    0
# Height    0
# dtype: int64

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=df[['Weight']]

# %%
y=df['Height']

# %%
# creating scatter plot

sns.scatterplot(df)
# Out:
# <Axes: >

# %%
# creating boxplot

sns.boxplot(x)
# Out:
# <Axes: >

# %%
sns.boxplot(y)
# Out:
# <Axes: ylabel='Height'>

# %%
# creating heatmap
sns.heatmap(df)
# Out:
# <Axes: >

# %%
import numpy as np

# %% [markdown]
# # checking for outlier

# %%
# function to check for outliers
def handle_outlier(column):
    q1=df[column].quantile(.25)
    q3=df[column].quantile(.75)
    iqr=q3-q1

    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)

    return  df[(df[column]<lower_range) | (df[column]>upper_range)]

# %%
handle_outlier('Weight')
# Out:
# Empty DataFrame
# Columns: [Weight, Height]
# Index: []

# %%
handle_outlier('Height')
# Out:
# Empty DataFrame
# Columns: [Weight, Height]
# Index: []

# %% [markdown]
# # Train test split

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=.3)

# %% [markdown]
# # scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
# scaling values

ss=StandardScaler()
x_train=ss.fit_transform(x_train)
x_test=ss.transform(x_test)

# %% [markdown]
# # making model

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# training model

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)
score=r2_score(y_test,y_pred)
score
# Out:
# 0.9086544902864333

# %%
# 9085792494774949 - when test size is .2 
# 9086544902864333 - when test size is .3

# %%
lr.predict(ss.transform([[45]]))
# Out:
# /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# array([132.23386663])
