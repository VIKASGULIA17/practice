# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df=pd.read_csv(r'/home/shino/Documents/Datasets/student_habits_performance.csv')

# %%
df
# Out:
#     student_id  age  gender  study_hours_per_day  social_media_hours  \
# 0        S1000   23  Female                  0.0                 1.2
# 1        S1001   20  Female                  6.9                 2.8
# 2        S1002   21    Male                  1.4                 3.1
# 3        S1003   23  Female                  1.0                 3.9
# 4        S1004   19  Female                  5.0                 4.4
# ..         ...  ...     ...                  ...                 ...
# 995      S1995   21  Female                  2.6                 0.5
# 996      S1996   17  Female                  2.9                 1.0
# 997      S1997   20    Male                  3.0                 2.6
# 998      S1998   24    Male                  5.4                 4.1
# 999      S1999   19  Female                  4.3                 2.9
#
#      netflix_hours part_time_job  attendance_percentage  sleep_hours  \
# ...

# %%
x=range(10,40)
y=np.linspace(0,80,30)

# %%
x2=[1,2,3,4]
y2=[[4,2,7,4],
   [12,5,3,7],
   [8,23,23,35]]

# %%
x3=['a','b','c','d']
y3=[32,45,65,13]

# %%
x6=[34,150,68,43,-34]

# %%
x7=['a','b','c','d']
y7=[32,45,65,13,43,45,234,267,46,75,23,345,7,345]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(18,18))

# Line Plot
ax1 = plt.subplot(3,3,1)
ax1.plot(x, y, linestyle='--', marker='o', label='Line data')
for i in range(len(x)):
    ax1.text(x[i], y[i], str(round(y[i],1)), fontsize=8)
ax1.set_title('Line Plot')
ax1.set_xlabel('x')
ax1.set_ylabel('y')
ax1.legend()

# Stack Plot
ax2 = plt.subplot(3,3,2)
ax2.stackplot(x2, y2, labels=['A','B','C','D'])
ax2.set_title('Stack Plot')
ax2.set_xlabel('x')
ax2.set_ylabel('y')
ax2.legend()

# Bar Chart
ax3 = plt.subplot(3,3,3)
bars = ax3.bar(x3, y3, color=['g', 'b','r', 'k'], label=['A','B','C','D'])
ax3.set_title('Bar Chart')
ax3.set_xlabel('x')
ax3.set_ylabel('y')
ax3.bar_label(bars)
ax3.legend()

# Horizontal Bar Chart
ax4 = plt.subplot(3,3,4)
bars_h = ax4.barh(x3, y3, color=['g', 'b','r', 'k'], label=['A','B','C','D'])
ax4.set_title('Horizontal Bar Chart')
ax4.set_xlabel('x')
ax4.set_ylabel('y')
ax4.bar_label(bars_h)
ax4.legend()

# Scatter Plot
ax5 = plt.subplot(3,3,5)
ax5.scatter(x, y, alpha=0.3, label='Points')
for i in range(len(x)):
    ax5.text(x[i], y[i], str(round(y[i],1)), fontsize=8)
ax5.set_title('Scatter Plot')
ax5.set_xlabel('x')
ax5.set_ylabel('y')
ax5.legend()

# Box Plot
ax6 = plt.subplot(3,3,6)
ax6.boxplot(x6)
ax6.set_title('Box Plot')
ax6.set_xlabel('x')
ax6.set_ylabel('y')

# Histogram
ax7 = plt.subplot(3,3,7)
ax7.hist(y7, bins=5, label='Histogram data')

ax7.set_title('Histogram')
ax7.set_xlabel('x')
ax7.set_ylabel('y')
ax7.legend()

# Violin Plot
ax8 = plt.subplot(3,3,8)
ax8.violinplot(y7)
ax8.set_title('Violin Plot')
ax8.set_xlabel('x')
ax8.set_ylabel('y')

# Pie Chart
ax9 = plt.subplot(3,3,9)
ax9.pie(y3, labels=x3, autopct='%1.1f%%')
ax9.set_title('Pie Chart')

plt.show()

# %%
import seaborn as sns

df=sns.load_dataset('titanic')

df.info()

df.duplicated().sum()

df.describe()

df.drop_duplicates(inplace=True)

df.reset_index(drop=True)

df.isnull().sum()
