# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data loading

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=df[df['species']!='virginica']

# %% [markdown]
# # information gathering

# %%
# checking dimensions 
df.shape
# Out:
# (100, 5)

# %%
df.count()
# Out:
# sepal_length    100
# sepal_width     100
# petal_length    100
# petal_width     100
# species         100
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  100 non-null    float64
#  1   sepal_width   100 non-null    float64
#  2   petal_length  100 non-null    float64
#  3   petal_width   100 non-null    float64
#  4   species       100 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 4.7+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    100.000000   100.000000    100.000000   100.000000
# mean       5.471000     3.099000      2.861000     0.786000
# std        0.641698     0.478739      1.449549     0.565153
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.000000     2.800000      1.500000     0.200000
# 50%        5.400000     3.050000      2.450000     0.800000
# 75%        5.900000     3.400000      4.325000     1.300000
# max        7.000000     4.400000      5.100000     1.800000

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa

# %%
df.sample(4)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 76           6.8          2.8           4.8          1.4  versicolor
# 9            4.9          3.1           1.5          0.1      setosa
# 22           4.6          3.6           1.0          0.2      setosa
# 40           5.0          3.5           1.3          0.3      setosa

# %%
df.tail(3)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor

# %% [markdown]
# # Data cleaning

# %%
# checking duplicates

df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            5.1          3.5           1.4          0.2      setosa
# 1            4.9          3.0           1.4          0.2      setosa
# 2            4.7          3.2           1.3          0.2      setosa
# 3            4.6          3.1           1.5          0.2      setosa
# 4            5.0          3.6           1.4          0.2      setosa
# ..           ...          ...           ...          ...         ...
# 95           5.7          3.0           4.2          1.2  versicolor
# 96           5.7          2.9           4.2          1.3  versicolor
# 97           6.2          2.9           4.3          1.3  versicolor
# 98           5.1          2.5           3.0          1.1  versicolor
# 99           5.7          2.8           4.1          1.3  versicolor
#
# [100 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=df.iloc[:,:4]
y=df.iloc[:,4]

# %%
x,y
# Out:
# (    sepal_length  sepal_width  petal_length  petal_width
#  0            5.1          3.5           1.4          0.2
#  1            4.9          3.0           1.4          0.2
#  2            4.7          3.2           1.3          0.2
#  3            4.6          3.1           1.5          0.2
#  4            5.0          3.6           1.4          0.2
#  ..           ...          ...           ...          ...
#  95           5.7          3.0           4.2          1.2
#  96           5.7          2.9           4.2          1.3
#  97           6.2          2.9           4.3          1.3
#  98           5.1          2.5           3.0          1.1
#  99           5.7          2.8           4.1          1.3
#
#  [100 rows x 4 columns],
#  0         setosa
#  1         setosa
#  2         setosa
#  3         setosa
#  4         setosa
#           ...
#  95    versicolor
#  96    versicolor
#  97    versicolor
#  98    versicolor
#  99    versicolor
#  Name: species, Length: 100, dtype: object)

# %%
# creating scatter plot

sns.scatterplot(df)
# Out:
# <Axes: >

# %%
# creating boxplot

sns.boxplot(x)
# Out:
# <Axes: >

# %%
sns.boxplot(x.iloc[:,1])
# Out:
# <Axes: ylabel='sepal_width'>

# %%
sns.regplot(x='sepal_length',y='petal_length',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# creating heatmap
sns.heatmap(x)
# Out:
# <Axes: >

# %%
import numpy as np

# %% [markdown]
# # checking for outlier

# %%
# function to check for outliers
def handle_outlier(column):
    q1=df[column].quantile(.25)
    q3=df[column].quantile(.75)
    iqr=q3-q1

    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)

    return  df[(df[column]<lower_range) & (df[column]>upper_range)]

# %%
handle_outlier('sepal_width')
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df.count()
# Out:
# sepal_length    145
# sepal_width     145
# petal_length    145
# petal_width     145
# species         145
# dtype: int64

# %%
df.species.unique()
# Out:
# array(['setosa', 'versicolor'], dtype=object)

# %%
# data transformation

df['species']=df['species'].map({'setosa':0,'versicolor':1})

# %% [markdown]
# # Train test split

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=8,test_size=.2)

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

for i in range(42):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.1)




    lr=LogisticRegression()
    lr.fit(x_train,y_train)


    y_pred=lr.predict(x_test)
    score=accuracy_score(y_test,y_pred)
    print(f"score at random state {i} is {score}")
# Out:
# score at random state 0 is 1.0
# score at random state 1 is 1.0
# score at random state 2 is 1.0
# score at random state 3 is 1.0
# score at random state 4 is 1.0
# score at random state 5 is 1.0
# score at random state 6 is 1.0
# score at random state 7 is 1.0
# score at random state 8 is 1.0
# score at random state 9 is 1.0
# score at random state 10 is 1.0
# score at random state 11 is 1.0
# score at random state 12 is 1.0
# score at random state 13 is 1.0
# score at random state 14 is 1.0
# score at random state 15 is 1.0
# score at random state 16 is 1.0
# score at random state 17 is 1.0
# score at random state 18 is 1.0
# score at random state 19 is 1.0
# score at random state 20 is 1.0
# score at random state 21 is 1.0
# score at random state 22 is 1.0
# score at random state 23 is 1.0
# score at random state 24 is 1.0
# score at random state 25 is 1.0
# score at random state 26 is 1.0
# score at random state 27 is 1.0
# score at random state 28 is 1.0
# score at random state 29 is 1.0
# score at random state 30 is 1.0
# score at random state 31 is 1.0
# score at random state 32 is 1.0
# score at random state 33 is 1.0
# score at random state 34 is 1.0
# score at random state 35 is 1.0
# score at random state 36 is 1.0
# score at random state 37 is 1.0
# score at random state 38 is 1.0
# score at random state 39 is 1.0
# score at random state 40 is 1.0
# score at random state 41 is 1.0

# %% [markdown]
# # making model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# training model

lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
score=accuracy_score(y_test,y_pred)
score
# Out:
# 1.0

# %%
# 9085792494774949 - when test size is .2 
# 9086544902864333 - when test size is .3
# 0.8487119973053087 -when test size is .35

# %%
lr.predict([[5.1,3.5,1.4,0.2]])
# Out:
# /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['setosa'], dtype=object)

# %%
df.head(3)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
