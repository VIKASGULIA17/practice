# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data loading

# %%
df=sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
df=df[df['species']!='setosa']

# %% [markdown]
# # information gathering

# %%
# checking dimensions 
df.shape
# Out:
# (100, 5)

# %%
df.count()
# Out:
# sepal_length    100
# sepal_width     100
# petal_length    100
# petal_width     100
# species         100
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 100 entries, 50 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  100 non-null    float64
#  1   sepal_width   100 non-null    float64
#  2   petal_length  100 non-null    float64
#  3   petal_width   100 non-null    float64
#  4   species       100 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 4.7+ KB

# %%
df.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    100.000000   100.000000    100.000000   100.000000
# mean       6.262000     2.872000      4.906000     1.676000
# std        0.662834     0.332751      0.825578     0.424769
# min        4.900000     2.000000      3.000000     1.000000
# 25%        5.800000     2.700000      4.375000     1.300000
# 50%        6.300000     2.900000      4.900000     1.600000
# 75%        6.700000     3.025000      5.525000     2.000000
# max        7.900000     3.800000      6.900000     2.500000

# %%
df.head(3)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 50           7.0          3.2           4.7          1.4  versicolor
# 51           6.4          3.2           4.5          1.5  versicolor
# 52           6.9          3.1           4.9          1.5  versicolor

# %%
df.sample(4)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 129           7.2          3.0           5.8          1.6   virginica
# 118           7.7          2.6           6.9          2.3   virginica
# 104           6.5          3.0           5.8          2.2   virginica
# 65            6.7          3.1           4.4          1.4  versicolor

# %%
df.tail(3)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %% [markdown]
# # Data cleaning

# %%
# checking duplicates

df.duplicated().sum()
# Out:
# np.int64(1)

# %%
df.drop_duplicates(inplace=True)
# Out:
# /tmp/ipykernel_37495/3006716147.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop_duplicates(inplace=True)

# %%
df.reset_index(drop=True)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width     species
# 0            7.0          3.2           4.7          1.4  versicolor
# 1            6.4          3.2           4.5          1.5  versicolor
# 2            6.9          3.1           4.9          1.5  versicolor
# 3            5.5          2.3           4.0          1.3  versicolor
# 4            6.5          2.8           4.6          1.5  versicolor
# ..           ...          ...           ...          ...         ...
# 94           6.7          3.0           5.2          2.3   virginica
# 95           6.3          2.5           5.0          1.9   virginica
# 96           6.5          3.0           5.2          2.0   virginica
# 97           6.2          3.4           5.4          2.3   virginica
# 98           5.9          3.0           5.1          1.8   virginica
#
# [99 rows x 5 columns]

# %%
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %% [markdown]
# # Visualisation

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x=df.iloc[:,:4]
y=df.iloc[:,4]

# %%
x,y
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width
#  50            7.0          3.2           4.7          1.4
#  51            6.4          3.2           4.5          1.5
#  52            6.9          3.1           4.9          1.5
#  53            5.5          2.3           4.0          1.3
#  54            6.5          2.8           4.6          1.5
#  ..            ...          ...           ...          ...
#  145           6.7          3.0           5.2          2.3
#  146           6.3          2.5           5.0          1.9
#  147           6.5          3.0           5.2          2.0
#  148           6.2          3.4           5.4          2.3
#  149           5.9          3.0           5.1          1.8
#
#  [99 rows x 4 columns],
#  50     versicolor
#  51     versicolor
#  52     versicolor
#  53     versicolor
#  54     versicolor
#            ...
#  145     virginica
#  146     virginica
#  147     virginica
#  148     virginica
#  149     virginica
#  Name: species, Length: 99, dtype: object)

# %%
# creating scatter plot

sns.scatterplot(df)
# Out:
# <Axes: >

# %%
# creating boxplot

sns.boxplot(x)
# Out:
# <Axes: >

# %%
sns.boxplot(x.iloc[:,1])
# Out:
# <Axes: ylabel='sepal_width'>

# %%
sns.regplot(x='sepal_length',y='petal_length',data=df)
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
# creating heatmap
sns.heatmap(x)
# Out:
# <Axes: >

# %%
import numpy as np

# %% [markdown]
# # checking for outlier

# %%
# function to check for outliers
def handle_outlier(column):
    q1=df[column].quantile(.25)
    q3=df[column].quantile(.75)
    iqr=q3-q1

    lower_range=q1-(1.5*iqr)
    upper_range=q3+(1.5*iqr)

    return  df[(df[column]<lower_range) & (df[column]>upper_range)]

# %%
handle_outlier('sepal_width')
# Out:
# Empty DataFrame
# Columns: [sepal_length, sepal_width, petal_length, petal_width, species]
# Index: []

# %%
df.count()
# Out:
# sepal_length    99
# sepal_width     99
# petal_length    99
# petal_width     99
# species         99
# dtype: int64

# %%
df.species.unique()
# Out:
# array(['versicolor', 'virginica'], dtype=object)

# %%
# data transformation

df['species']=df['species'].map({'virginica':0,'versicolor':1})
# Out:
# /tmp/ipykernel_37495/429647174.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['species']=df['species'].map({'virginica':0,'versicolor':1})

# %% [markdown]
# # Train test split

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=15,test_size=.2)

# %%
# spliting data into train and test
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

for i in range(42):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=.2)




    lr=LogisticRegression()
    lr.fit(x_train,y_train)


    y_pred=lr.predict(x_test)
    score=accuracy_score(y_test,y_pred)
    print(f"score at random state {i} is {score}")
# Out:
# score at random state 0 is 0.9
# score at random state 1 is 0.9
# score at random state 2 is 0.85
# score at random state 3 is 0.95
# score at random state 4 is 0.95
# score at random state 5 is 0.95
# score at random state 6 is 0.95
# score at random state 7 is 0.9
# score at random state 8 is 0.95
# score at random state 9 is 0.95
# score at random state 10 is 0.95
# score at random state 11 is 0.95
# score at random state 12 is 1.0
# score at random state 13 is 0.95
# score at random state 14 is 1.0
# score at random state 15 is 1.0
# score at random state 16 is 0.9
# score at random state 17 is 0.95
# score at random state 18 is 1.0
# score at random state 19 is 1.0
# score at random state 20 is 0.85
# score at random state 21 is 0.95
# score at random state 22 is 0.9
# score at random state 23 is 0.95
# score at random state 24 is 0.8
# score at random state 25 is 0.85
# score at random state 26 is 0.9
# score at random state 27 is 0.95
# score at random state 28 is 0.95
# score at random state 29 is 0.95
# score at random state 30 is 0.95
# score at random state 31 is 0.9
# score at random state 32 is 0.95
# score at random state 33 is 1.0
# score at random state 34 is 1.0
# score at random state 35 is 0.95
# score at random state 36 is 0.9
# score at random state 37 is 0.95
# score at random state 38 is 1.0
# score at random state 39 is 0.95
# score at random state 40 is 0.9
# score at random state 41 is 0.9

# %% [markdown]
# # making model

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# training model

lr=LogisticRegression()
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)
score=accuracy_score(y_test,y_pred)
score
# Out:
# 0.9

# %%
# 9085792494774949 - when test size is .2 
# 9086544902864333 - when test size is .3
# 0.8487119973053087 -when test size is .35

# %%
lr.predict([[5.1,3.5,1.4,0.2]])
# Out:
# /usr/lib/python3.13/site-packages/sklearn/utils/validation.py:2749: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array(['versicolor'], dtype=object)

# %%
df.head(3)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width  species
# 50           7.0          3.2           4.7          1.4        1
# 51           6.4          3.2           4.5          1.5        1
# 52           6.9          3.1           4.9          1.5        1
