# %%
import pandas as pd

# %%
df=pd.read_csv('mtcars2.csv')

df.duplicated().sum()

df.isnull().sum()

df['qsec'].fillna(df['qsec'].mean(),inplace=True)

df.rename(columns={'Unnamed: 1':'name'},inplace=True)

df.sort_values(by='name',inplace=True)

df

df[df['disp']>300]

# %%
df=pd.read_csv('IMBD.csv')

# %%
df
# Out:
#                        title         year certificate duration  \
# 0                  Cobra Kai     (2018– )       TV-14   30 min
# 1                  The Crown     (2016– )       TV-MA   58 min
# 2           Better Call Saul  (2015–2022)       TV-MA   46 min
# 3              Devil in Ohio       (2022)       TV-MA  356 min
# 4     Cyberpunk: Edgerunners     (2022– )       TV-MA   24 min
# ...                      ...          ...         ...      ...
# 9952          The Imperfects     (2022– )       TV-MA   45 min
# 9953        The Walking Dead  (2010–2022)       TV-MA   44 min
# 9954               The Crown     (2016– )       TV-MA   58 min
# 9955            Supernatural  (2005–2020)       TV-14   44 min
# 9956           Devil in Ohio       (2022)       TV-MA  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# ...

# %%
df.isnull().sum()
# Out:
# title             0
# year            527
# certificate    3453
# duration       2036
# genre            73
# rating         1173
# description       0
# stars             0
# votes          1173
# dtype: int64

# %%
df.drop(columns=['description','certificate'],inplace=True)

# %%
df['duration'].fillna(df['duration'].mode()[0],inplace=True)

df['rating'].fillna(df['rating'].median(),inplace=True)


df['year'].fillna(df['year'].mode()[0],inplace=True)

df['genre'].fillna(df['genre'].mode()[0],inplace=True)
# Out:
# C:\Users\osame\AppData\Local\Temp\ipykernel_7028\949606119.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['duration'].fillna(df['duration'].mode()[0],inplace=True)
# C:\Users\osame\AppData\Local\Temp\ipykernel_7028\949606119.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
(df.isnull().sum()/df.shape[0])*100
# Out:
# title        0.000000
# year         0.000000
# duration     0.000000
# genre        0.000000
# rating       0.000000
# stars        0.000000
# votes       11.780657
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9957 non-null   object
#  1   year      9957 non-null   object
#  2   duration  9957 non-null   object
#  3   genre     9957 non-null   object
#  4   rating    9957 non-null   float64
#  5   stars     9957 non-null   object
#  6   votes     8784 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 544.7+ KB

# %%
df['votes'].fillna(df['votes'].mode()[0],inplace=True)
# Out:
# C:\Users\osame\AppData\Local\Temp\ipykernel_7028\1504884790.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['votes'].fillna(df['votes'].mode()[0],inplace=True)

# %%
df['votes'].mode()[0]
# Out:
# '30'

# %%
df.iloc[[1,35,5],[1,3,5]]
# Out:
#         year                      genre  \
# 1   (2016– )  Biography, Drama, History
# 35  (2019– )   Action, Adventure, Drama
# 5   (2022– )     Drama, Fantasy, Horror
#
#                                                 stars
# 1   ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...
# 35  ['Henry Cavill, ', 'Freya Allan, ', 'Anya Chal...
# 5   ['Tom Sturridge, ', 'Boyd Holbrook, ', 'Patton...

# %%
df.sort_values(by='rating',ascending=True)
# Out:
#                                  title         year duration  \
# 6633                       Defcon 2012       (2010)   92 min
# 6033       Hajwala: The Missing Engine       (2016)   96 min
# 4987                Way of the Vampire       (2005)   82 min
# 3612                    The Hype House     (2022– )   36 min
# 3357  Thomas & Friends: All Engines Go     (2021– )   30 min
# ...                                ...          ...      ...
# 8557          JoJo's Bizarre Adventure     (2012– )   25 min
# 8161        Avatar: The Last Airbender  (2005–2008)   25 min
# 8259                            Dexter  (2006–2013)   56 min
# 8907        Avatar: The Last Airbender  (2005–2008)   24 min
# 9444                   BoJack Horseman  (2014–2020)   26 min
#
#                              genre  rating  \
# 6633                        Sci-Fi     1.7
# 6033      Action, Adventure, Crime     2.0
# 4987      Action, Horror, Thriller     2.0
# 3612                    Reality-TV     2.1
# ...

# %%
df.iloc[1:3,4:6]
# Out:
#    rating                                              stars
# 1     8.7  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...
# 2     8.9  ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...

# %%
df.loc[1:3,'stars':]
# Out:
#                                                stars    votes
# 1  ['Claire Foy, ', 'Olivia Colman, ', 'Imelda St...  199,885
# 2  ['Bob Odenkirk, ', 'Rhea Seehorn, ', 'Jonathan...  501,384
# 3  ['Emily Deschanel, ', 'Sam Jaeger, ', 'Gerardo...    9,773

# %%
import matplotlib.pyplot as plt

# %%
pwd
# Out:
# 'C:\\Users\\osame\\Ai summer training'

# %%
# Out:
#   Cell In[25], line 6
#     bar chart
#         ^
# SyntaxError: invalid syntax

# %%
# f.open()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9957 non-null   object
#  1   year      9957 non-null   object
#  2   duration  9957 non-null   object
#  3   genre     9957 non-null   object
#  4   rating    9957 non-null   float64
#  5   stars     9957 non-null   object
#  6   votes     9957 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 544.7+ KB

# %%
plt.plot(df['year'],df['rating'])
plt.show()

# %%
# plt.scatter

# %%
df.shape
# Out:
# (9957, 7)

# %%
x=range(9957)
y=df['rating']
plt.bar(x,y,color='k')
# Out:
# <BarContainer object of 9957 artists>

# %%
plt.scatter(x,y,alpha=.9)

# %%
f=open('vikas2.txt','w')
f.write('vikas\n')
f.write('Iitm\n')
f.write('Bca\n')
f.write('05813702023\n')
f.write('Morining\n')
f.write('Janakpuri\n')
f.close()

# %%
f=open('vikas2.txt','r')
l=f.readlines()
l.pop(0)
l.pop(-1)
f.close()
#write
f=open('vikas2.txt','w')
for i in l:
    f.write(i)
f.close()
# Out:
# ['vikas\n', 'Iitm\n', 'Bca\n', '05813702023\n', 'Morining\n', 'Janakpuri\n']
# ['Iitm\n', 'Bca\n', '05813702023\n', 'Morining\n']

# %%
f=open('vikas2.txt','r')
l=f.readlines()
print(l)
# Out:
# ['Iitm\n', 'Bca\n', '05813702023\n', 'Morining\n']

# %%
import os
if os.path.exists('vikas1.txt'):
    os.remove('vikas1.txt')
    print("file successfully deleted!")
else:
    print("not exist")
# Out:
# file successfully deleted!

# %%
df
# Out:
#                        title         year duration  \
# 0                  Cobra Kai     (2018– )   30 min
# 1                  The Crown     (2016– )   58 min
# 2           Better Call Saul  (2015–2022)   46 min
# 3              Devil in Ohio       (2022)  356 min
# 4     Cyberpunk: Edgerunners     (2022– )   24 min
# ...                      ...          ...      ...
# 9952          The Imperfects     (2022– )   45 min
# 9953        The Walking Dead  (2010–2022)   44 min
# 9954               The Crown     (2016– )   58 min
# 9955            Supernatural  (2005–2020)   44 min
# 9956           Devil in Ohio       (2022)  356 min
#
#                              genre  rating  \
# 0            Action, Comedy, Drama     8.5
# 1        Biography, Drama, History     8.7
# 2                     Crime, Drama     8.9
# 3           Drama, Horror, Mystery     5.9
# 4     Animation, Action, Adventure     8.6
# ...                            ...     ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9957 entries, 0 to 9956
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     9957 non-null   object
#  1   year      9957 non-null   object
#  2   duration  9957 non-null   object
#  3   genre     9957 non-null   object
#  4   rating    9957 non-null   float64
#  5   stars     9957 non-null   object
#  6   votes     9957 non-null   int64
# dtypes: float64(1), int64(1), object(5)
# memory usage: 544.7+ KB

# %%
def remove_comma(data):
    return int(data.replace(',', ''))

# %%
df['votes']=df['votes'].apply(remove_comma)

# %%
x=df['rating']
y=df['votes']
plt.plot(x,y)

# %%
plt.scatter(x,y)

# %%
plt.bar(df['year'],y)
# Out:
# <BarContainer object of 9957 artists>
