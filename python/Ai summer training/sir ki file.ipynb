# %%
import pandas as pd

# %% [markdown]
# # data loading

# %%
df=pd.read_csv('mtcars2.csv')

# %% [markdown]
# # Data gathering

# %%
df.shape

df.info()

df.head()

df.tail()

df.sample()

df.describe().T

df.count()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32 entries, 0 to 31
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   S.No        32 non-null     int64
#  1   Unnamed: 1  32 non-null     object
#  2   mpg         32 non-null     float64
#  3   cyl         32 non-null     int64
#  4   disp        32 non-null     float64
#  5   hp          32 non-null     int64
#  6   drat        32 non-null     float64
#  7   wt          32 non-null     float64
#  8   qsec        29 non-null     float64
#  9   vs          32 non-null     int64
#  10  am          32 non-null     int64
#  11  gear        32 non-null     int64
#  12  carb        32 non-null     int64
# dtypes: float64(5), int64(7), object(1)
# memory usage: 3.4+ KB
# 0

# %% [markdown]
# # data cleaning

# %%
df.duplicated().sum()

df.isnull().sum()

df['qsec'].fillna(df['qsec'].mean(),inplace=True)

df.rename(columns={'Unnamed: 1':'name'},inplace=True)

df.sort_values(by='name',inplace=True)

df

df[df['disp']>300]
# Out:
# C:\Users\osame\AppData\Local\Temp\ipykernel_1180\42866809.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['qsec'].fillna(df['qsec'].mean(),inplace=True)
#     S.No                 name   mpg  cyl   disp   hp  drat     wt   qsec  vs  \
# 22    23          AMC Javelin  15.2    8  304.0  150  3.15  3.435  17.30   0
# 14    15   Cadillac Fleetwood  10.4    8  472.0  205  2.93  5.250  17.98   0
# 23    24           Camaro Z28  13.3    8  350.0  245  3.73  3.840  15.41   0
# ...

# %%
df.loc[[1,2,3],['cyl','qsec']]
# Out:
#    cyl   qsec
# 1    6  17.02
# 2    4  18.61
# 3    6  19.44

# %%
import matplotlib.pyplot as plt

x=range(32)
y=df['disp']
plt.plot(x,y,marker='o')

# %%
x=range(32)
y=df['hp']
plt.bar(x,y)
# Out:
# <BarContainer object of 32 artists>

# %%
x=range(32)
y=df['hp']
plt.scatter(x,y)

# %%
x=range(32)
y=df['hp']
y1=df['wt']
plt.stackplot(x,y)
plt.stackplot(x,y1)

# %%
import numpy as np

# %%
x=range(20)
y=np.linspace(20,40,20)

# %%
plt.figure(figsize=(10,5))
plt.title("line plot",fontdict={'fontsize':40,'fontweight':40},fontstyle='italic')
plt.xlabel("no of range")
plt.ylabel("no from linspace")
plt.grid(True)
plt.plot(x,y,marker='s',color='g',linewidth=3,alpha=.2)

for i in range(20):
    plt.text(i,y[i],str(round((y[i]))),fontsize=10)

# %%
# create 5 lines in 1 plot which is non parellel and no intersecting
# create a stack plot for seven data points with 5 stack 
# create a horizontal bar chart for 7 company names and thier employee count 
# create a vertical bar chart for 7 bike names and their prices

# %%
x = np.linspace(0, 10, 20)
y = np.linspace(11, 23, 40)
z = np.linspace(24, 50,25)
n = np.linspace(52, 67, 35)
m = np.linspace(70, 80, 54)
plt.figure(figsize=(8, 5))

plt.plot(x)
plt.plot(y)
plt.plot(z)
plt.plot(n)
plt.plot(m)

plt.title("q")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
#2 
data = range(1, 8)
a = [2, 3, 4, 5, 4, 3, 2]
b = [1, 2, 1, 3, 2, 1, 1]
c = [2, 1, 2, 1, 2, 1, 2]
d = [3, 2, 2, 2, 3, 3, 2]
e = [1, 2, 3, 2, 1, 2, 3]

plt.figure(figsize=(8, 5))
plt.stackplot(data, a, b, c, d, e)
plt.title("question number 2")
plt.xlabel("data points")
plt.ylabel("Value")
plt.show()

# %%
# q3
company = ['Apple', 'Google', 'Microsoft', 'Amazon', 'Tesla', 'Meta', 'Netflix']
emp = [150000, 120000, 180000, 160000, 100000, 80000, 70000]

plt.figure(figsize=(8, 5))
plt.barh(company, emp, color=['r','k','g'])
plt.title("q3")
plt.xlabel("Employees")
plt.ylabel("Company")
plt.show()

# %%
x = ['Bullet', 'Yamaha', 'KTM', 'Bajaj', 'Royal Enfield', 'Honda', 'BMW']
y = [180000, 130000, 160000, 140000, 150000, 125000, 220000]

plt.figure(figsize=(8, 5))
plt.bar(x, y, color=['r','k','g'])
plt.title("q4")
plt.xlabel("name")
plt.ylabel("Price ")
plt.show()
